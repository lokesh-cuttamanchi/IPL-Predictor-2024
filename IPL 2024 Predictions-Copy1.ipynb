# %% [markdown]
# <font size="20">IPL 2024 PREDICTIONS 🏏🏆

# %%
import pandas as pd 
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Overview of the Dataset:
#
# - The dataset comprises two distinct CSV files: "matches" and "deliveries." These files encompass the summary of each match and detailed information regarding each ball bowled, respectively.
#
# - The dataset is updated up to the IPL season of 2023.
#
# - [IPL Complete Dataset (2008-2023)](https://www.kaggle.com/datasets/patrickb1912/ipl-complete-dataset-20082020/data)

# %% [markdown]
# <font size="5">Loading First Dataset <font size="3">(https://www.kaggle.com/datasets/patrickb1912/ipl-complete-dataset-20082020/data?select=deliveries.csv)

# %%
first_dataset = pd.read_csv("C:/Users/Loki/Documents/IPL 2024 Predictions/deliveries.csv")
first_dataset
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 243812   1370353       2    Chennai Super Kings               Gujarat Titans
# 243813   1370353       2    Chennai Super Kings               Gujarat Titans
# 243814   1370353       2    Chennai Super Kings               Gujarat Titans
# 243815   1370353       2    Chennai Super Kings               Gujarat Titans
# 243816   1370353       2    Chennai Super Kings               Gujarat Titans
#
#         over  ball       batter     bowler  non_striker  batsman_runs  \
# 0          0     1   SC Ganguly    P Kumar  BB McCullum             0
# 1          0     2  BB McCullum    P Kumar   SC Ganguly             0
# 2          0     3  BB McCullum    P Kumar   SC Ganguly             0
# 3          0     4  BB McCullum    P Kumar   SC Ganguly             0
# 4          0     5  BB McCullum    P Kumar   SC Ganguly             0
# ...      ...   ...          ...        ...          ...           ...
# 243812    14     2       S Dube  MM Sharma    RA Jadeja             1
# 243813    14     3    RA Jadeja  MM Sharma       S Dube             1
# 243814    14     4       S Dube  MM Sharma    RA Jadeja             1
# 243815    14     5    RA Jadeja  MM Sharma       S Dube             6
# 243816    14     6    RA Jadeja  MM Sharma       S Dube             4
#
#         extra_runs  total_runs extras_type  is_wicket player_dismissed  \
# 0                1           1     legbyes          0              NaN
# 1                0           0         NaN          0              NaN
# 2                1           1       wides          0              NaN
# 3                0           0         NaN          0              NaN
# 4                0           0         NaN          0              NaN
# ...            ...         ...         ...        ...              ...
# 243812           0           1         NaN          0              NaN
# 243813           0           1         NaN          0              NaN
# 243814           0           1         NaN          0              NaN
# 243815           0           6         NaN          0              NaN
# 243816           0           4         NaN          0              NaN
#
#        dismissal_kind fielder
# 0                 NaN     NaN
# 1                 NaN     NaN
# 2                 NaN     NaN
# 3                 NaN     NaN
# 4                 NaN     NaN
# ...               ...     ...
# 243812            NaN     NaN
# 243813            NaN     NaN
# 243814            NaN     NaN
# 243815            NaN     NaN
# 243816            NaN     NaN
#
# [243817 rows x 17 columns]

# %% [markdown]
# <font size="5">Loading Second Dataset <font size="3">(https://www.kaggle.com/datasets/patrickb1912/ipl-complete-dataset-20082020/data?select=matches.csv)

# %%
second_dataset = pd.read_csv("C:/Users/Loki/Documents/IPL 2024 Predictions/matches.csv")
second_dataset
# Out:
#            id   season        city        date   match_type player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League     BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League      MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League     MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League      MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League       DJ Hussey
# ...       ...      ...         ...         ...          ...             ...
# 1019  1359544     2023   Bengaluru  2023-05-21       League    Shubman Gill
# 1020  1370350     2023     Chennai  2023-05-23  Qualifier 1      RD Gaikwad
# 1021  1370351     2023     Chennai  2023-05-24   Eliminator   Akash Madhwal
# 1022  1370352     2023   Ahmedabad  2023-05-26  Qualifier 2    Shubman Gill
# 1023  1370353     2023   Ahmedabad  2023-05-29        Final       DP Conway
#
#                                            venue                        team1  \
# 0                          M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1     Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                               Feroz Shah Kotla             Delhi Daredevils
# 3                               Wankhede Stadium               Mumbai Indians
# 4                                   Eden Gardens        Kolkata Knight Riders
# ...                                          ...                          ...
# 1019            M Chinnaswamy Stadium, Bengaluru  Royal Challengers Bangalore
# 1020    MA Chidambaram Stadium, Chepauk, Chennai          Chennai Super Kings
# 1021    MA Chidambaram Stadium, Chepauk, Chennai               Mumbai Indians
# 1022            Narendra Modi Stadium, Ahmedabad               Gujarat Titans
# 1023            Narendra Modi Stadium, Ahmedabad               Gujarat Titans
#
#                             team2                  toss_winner toss_decision  \
# 0           Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1             Chennai Super Kings          Chennai Super Kings           bat
# 2                Rajasthan Royals             Rajasthan Royals           bat
# 3     Royal Challengers Bangalore               Mumbai Indians           bat
# 4                 Deccan Chargers              Deccan Chargers           bat
# ...                           ...                          ...           ...
# 1019               Gujarat Titans               Gujarat Titans         field
# 1020               Gujarat Titans               Gujarat Titans         field
# 1021         Lucknow Super Giants               Mumbai Indians           bat
# 1022               Mumbai Indians               Mumbai Indians         field
# 1023          Chennai Super Kings          Chennai Super Kings         field
#
#                            winner   result  result_margin  target_runs  \
# 0           Kolkata Knight Riders     runs          140.0        223.0
# 1             Chennai Super Kings     runs           33.0        241.0
# 2                Delhi Daredevils  wickets            9.0        130.0
# 3     Royal Challengers Bangalore  wickets            5.0        166.0
# 4           Kolkata Knight Riders  wickets            5.0        111.0
# ...                           ...      ...            ...          ...
# 1019               Gujarat Titans  wickets            6.0        198.0
# 1020          Chennai Super Kings     runs           15.0        173.0
# 1021               Mumbai Indians     runs           81.0        183.0
# 1022               Gujarat Titans     runs           62.0        234.0
# 1023          Chennai Super Kings  wickets            5.0        171.0
#
#       target_overs super_over method       umpire1         umpire2
# 0             20.0          N    NaN     Asad Rauf     RE Koertzen
# 1             20.0          N    NaN     MR Benson      SL Shastri
# 2             20.0          N    NaN     Aleem Dar  GA Pratapkumar
# 3             20.0          N    NaN      SJ Davis       DJ Harper
# 4             20.0          N    NaN     BF Bowden     K Hariharan
# ...            ...        ...    ...           ...             ...
# 1019          20.0          N    NaN   Nitin Menon       VK Sharma
# 1020          20.0          N    NaN  AK Chaudhary     CB Gaffaney
# 1021          20.0          N    NaN  BNJ Oxenford       VK Sharma
# 1022          20.0          N    NaN   Nitin Menon       RJ Tucker
# 1023          15.0          N    D/L   Nitin Menon       RJ Tucker
#
# [1024 rows x 20 columns]

# %% [markdown]
# <font size="5">Data Cleaning

# %%
#Finding Total Runs Scored in each innings
total_runs = first_dataset.groupby(['match_id','inning']).sum()['total_runs'].add(1).reset_index()
total_runs.head(10)
# Out:
#    match_id  inning  total_runs
# 0    335982       1         223
# 1    335982       2          83
# 2    335983       1         241
# 3    335983       2         208
# 4    335984       1         130
# 5    335984       2         133
# 6    335985       1         166
# 7    335985       2         167
# 8    335986       1         111
# 9    335986       2         113

# %%
#selecting only first innings to find target score for each match
total_runs = total_runs[total_runs['inning'] == 1]
total_runs
# Out:
#       match_id  inning  total_runs
# 0       335982       1         223
# 2       335983       1         241
# 4       335984       1         130
# 6       335985       1         166
# 8       335986       1         111
# ...        ...     ...         ...
# 2065   1359544       1         198
# 2067   1370350       1         173
# 2069   1370351       1         183
# 2071   1370352       1         234
# 2073   1370353       1         215
#
# [1024 rows x 3 columns]

# %%
#merging total runs df with second dataset
match_df = second_dataset.merge(total_runs[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
match_df
# Out:
#            id   season        city        date   match_type player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League     BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League      MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League     MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League      MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League       DJ Hussey
# ...       ...      ...         ...         ...          ...             ...
# 1019  1359544     2023   Bengaluru  2023-05-21       League    Shubman Gill
# 1020  1370350     2023     Chennai  2023-05-23  Qualifier 1      RD Gaikwad
# 1021  1370351     2023     Chennai  2023-05-24   Eliminator   Akash Madhwal
# 1022  1370352     2023   Ahmedabad  2023-05-26  Qualifier 2    Shubman Gill
# 1023  1370353     2023   Ahmedabad  2023-05-29        Final       DP Conway
#
#                                            venue                        team1  \
# 0                          M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1     Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                               Feroz Shah Kotla             Delhi Daredevils
# 3                               Wankhede Stadium               Mumbai Indians
# 4                                   Eden Gardens        Kolkata Knight Riders
# ...                                          ...                          ...
# 1019            M Chinnaswamy Stadium, Bengaluru  Royal Challengers Bangalore
# 1020    MA Chidambaram Stadium, Chepauk, Chennai          Chennai Super Kings
# 1021    MA Chidambaram Stadium, Chepauk, Chennai               Mumbai Indians
# 1022            Narendra Modi Stadium, Ahmedabad               Gujarat Titans
# 1023            Narendra Modi Stadium, Ahmedabad               Gujarat Titans
#
#                             team2                  toss_winner  ...   result  \
# 0           Kolkata Knight Riders  Royal Challengers Bangalore  ...     runs
# 1             Chennai Super Kings          Chennai Super Kings  ...     runs
# 2                Rajasthan Royals             Rajasthan Royals  ...  wickets
# 3     Royal Challengers Bangalore               Mumbai Indians  ...  wickets
# 4                 Deccan Chargers              Deccan Chargers  ...  wickets
# ...                           ...                          ...  ...      ...
# 1019               Gujarat Titans               Gujarat Titans  ...  wickets
# 1020               Gujarat Titans               Gujarat Titans  ...     runs
# 1021         Lucknow Super Giants               Mumbai Indians  ...     runs
# 1022               Mumbai Indians               Mumbai Indians  ...     runs
# 1023          Chennai Super Kings          Chennai Super Kings  ...  wickets
#
#      result_margin target_runs  target_overs  super_over  method  \
# 0            140.0       223.0          20.0           N     NaN
# 1             33.0       241.0          20.0           N     NaN
# 2              9.0       130.0          20.0           N     NaN
# 3              5.0       166.0          20.0           N     NaN
# 4              5.0       111.0          20.0           N     NaN
# ...            ...         ...           ...         ...     ...
# 1019           6.0       198.0          20.0           N     NaN
# 1020          15.0       173.0          20.0           N     NaN
# 1021          81.0       183.0          20.0           N     NaN
# 1022          62.0       234.0          20.0           N     NaN
# 1023           5.0       171.0          15.0           N     D/L
#
#            umpire1         umpire2 match_id total_runs
# 0        Asad Rauf     RE Koertzen   335982        223
# 1        MR Benson      SL Shastri   335983        241
# 2        Aleem Dar  GA Pratapkumar   335984        130
# 3         SJ Davis       DJ Harper   335985        166
# 4        BF Bowden     K Hariharan   335986        111
# ...            ...             ...      ...        ...
# 1019   Nitin Menon       VK Sharma  1359544        198
# 1020  AK Chaudhary     CB Gaffaney  1370350        173
# 1021  BNJ Oxenford       VK Sharma  1370351        183
# 1022   Nitin Menon       RJ Tucker  1370352        234
# 1023   Nitin Menon       RJ Tucker  1370353        215
#
# [1024 rows x 22 columns]

# %%
match_df = match_df[['match_id','city','winner','total_runs']]

# %%
match_df = match_df.rename(columns={'id':'match_id'})

# %%
second_innings = match_df.merge(first_dataset,on='match_id')
second_innings
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 0         335982  Bangalore  Kolkata Knight Riders           223       1
# 1         335982  Bangalore  Kolkata Knight Riders           223       1
# 2         335982  Bangalore  Kolkata Knight Riders           223       1
# 3         335982  Bangalore  Kolkata Knight Riders           223       1
# 4         335982  Bangalore  Kolkata Knight Riders           223       1
# ...          ...        ...                    ...           ...     ...
# 243812   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243813   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243814   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243815   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243816   1370353  Ahmedabad    Chennai Super Kings           215       2
#
#                  batting_team                 bowling_team  over  ball  \
# 0       Kolkata Knight Riders  Royal Challengers Bangalore     0     1
# 1       Kolkata Knight Riders  Royal Challengers Bangalore     0     2
# 2       Kolkata Knight Riders  Royal Challengers Bangalore     0     3
# 3       Kolkata Knight Riders  Royal Challengers Bangalore     0     4
# 4       Kolkata Knight Riders  Royal Challengers Bangalore     0     5
# ...                       ...                          ...   ...   ...
# 243812    Chennai Super Kings               Gujarat Titans    14     2
# 243813    Chennai Super Kings               Gujarat Titans    14     3
# 243814    Chennai Super Kings               Gujarat Titans    14     4
# 243815    Chennai Super Kings               Gujarat Titans    14     5
# 243816    Chennai Super Kings               Gujarat Titans    14     6
#
#              batter     bowler  non_striker  batsman_runs  extra_runs  \
# 0        SC Ganguly    P Kumar  BB McCullum             0           1
# 1       BB McCullum    P Kumar   SC Ganguly             0           0
# 2       BB McCullum    P Kumar   SC Ganguly             0           1
# 3       BB McCullum    P Kumar   SC Ganguly             0           0
# 4       BB McCullum    P Kumar   SC Ganguly             0           0
# ...             ...        ...          ...           ...         ...
# 243812       S Dube  MM Sharma    RA Jadeja             1           0
# 243813    RA Jadeja  MM Sharma       S Dube             1           0
# 243814       S Dube  MM Sharma    RA Jadeja             1           0
# 243815    RA Jadeja  MM Sharma       S Dube             6           0
# 243816    RA Jadeja  MM Sharma       S Dube             4           0
#
#         total_runs_y extras_type  is_wicket player_dismissed dismissal_kind  \
# 0                  1     legbyes          0              NaN            NaN
# 1                  0         NaN          0              NaN            NaN
# 2                  1       wides          0              NaN            NaN
# 3                  0         NaN          0              NaN            NaN
# 4                  0         NaN          0              NaN            NaN
# ...              ...         ...        ...              ...            ...
# 243812             1         NaN          0              NaN            NaN
# 243813             1         NaN          0              NaN            NaN
# 243814             1         NaN          0              NaN            NaN
# 243815             6         NaN          0              NaN            NaN
# 243816             4         NaN          0              NaN            NaN
#
#        fielder
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 243812     NaN
# 243813     NaN
# 243814     NaN
# 243815     NaN
# 243816     NaN
#
# [243817 rows x 20 columns]

# %%
second_innings = second_innings[second_innings['inning']==2]
second_innings.shape
# Out:
# (117531, 20)

# %% [markdown]
# Data Cleaning (removing old and repeating teams)

# %%
second_innings['batting_team'].value_counts()
# Out:
# batting_team
# Kolkata Knight Riders          14310
# Mumbai Indians                 13680
# Royal Challengers Bangalore    13426
# Rajasthan Royals               12290
# Chennai Super Kings            11838
# Kings XI Punjab                10753
# Delhi Daredevils               10027
# Sunrisers Hyderabad             9518
# Delhi Capitals                  5061
# Deccan Chargers                 3754
# Pune Warriors                   2995
# Gujarat Titans                  2143
# Gujarat Lions                   1832
# Lucknow Super Giants            1805
# Punjab Kings                    1756
# Rising Pune Supergiant           906
# Rising Pune Supergiants          731
# Kochi Tuskers Kerala             706
# Name: count, dtype: int64

# %%
teams = ['Kolkata Knight Riders', 
         'Chennai Super Kings',
         'Punjab Kings', 
         'Rajasthan Royals',
         'Mumbai Indians',
         'Delhi Capitals',
         'Royal Challengers Bangalore',
         'Sunrisers Hyderabad',
         'Lucknow Super Giants',
         'Gujarat Titans'
         ]

# %%
second_innings['batting_team'] = second_innings['batting_team'].str.replace('Delhi Daredevils','Delhi Capitals')
second_innings['bowling_team'] = second_innings['bowling_team'].str.replace('Delhi Daredevils','Delhi Capitals')

second_innings['batting_team'] = second_innings['batting_team'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
second_innings['bowling_team'] = second_innings['bowling_team'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

second_innings['batting_team'] = second_innings['batting_team'].str.replace('Kings XI Punjab','Punjab Kings')
second_innings['bowling_team'] = second_innings['bowling_team'].str.replace('Kings XI Punjab','Punjab Kings')

# %%
second_innings['batting_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Punjab Kings', 'Delhi Capitals',
#        'Kolkata Knight Riders', 'Rajasthan Royals', 'Mumbai Indians',
#        'Chennai Super Kings', 'Sunrisers Hyderabad', 'Pune Warriors',
#        'Kochi Tuskers Kerala', 'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Gujarat Titans', 'Lucknow Super Giants'],
#       dtype=object)

# %%
second_innings = second_innings[second_innings['batting_team'].isin(teams)]
second_innings = second_innings[second_innings['bowling_team'].isin(teams)]

# %%
second_innings['batting_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Punjab Kings', 'Delhi Capitals',
#        'Kolkata Knight Riders', 'Rajasthan Royals', 'Mumbai Indians',
#        'Chennai Super Kings', 'Sunrisers Hyderabad', 'Gujarat Titans',
#        'Lucknow Super Giants'], dtype=object)

# %%
second_innings.shape
# Out:
# (104595, 20)

# %%
#finding current score with cumsum method
second_innings['current_Score'] = second_innings.groupby('match_id')['total_runs_y'].cumsum()

# %%
second_innings
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           223       2
# 125       335982  Bangalore  Kolkata Knight Riders           223       2
# 126       335982  Bangalore  Kolkata Knight Riders           223       2
# 127       335982  Bangalore  Kolkata Knight Riders           223       2
# 128       335982  Bangalore  Kolkata Knight Riders           223       2
# ...          ...        ...                    ...           ...     ...
# 243812   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243813   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243814   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243815   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243816   1370353  Ahmedabad    Chennai Super Kings           215       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 243812          Chennai Super Kings         Gujarat Titans    14     2
# 243813          Chennai Super Kings         Gujarat Titans    14     3
# 243814          Chennai Super Kings         Gujarat Titans    14     4
# 243815          Chennai Super Kings         Gujarat Titans    14     5
# 243816          Chennai Super Kings         Gujarat Titans    14     6
#
#            batter  ... non_striker batsman_runs  extra_runs  total_runs_y  \
# 124      R Dravid  ...    W Jaffer            1           0             1
# 125      W Jaffer  ...    R Dravid            0           1             1
# 126      W Jaffer  ...    R Dravid            0           0             0
# 127      W Jaffer  ...    R Dravid            1           0             1
# 128      R Dravid  ...    W Jaffer            1           0             1
# ...           ...  ...         ...          ...         ...           ...
# 243812     S Dube  ...   RA Jadeja            1           0             1
# 243813  RA Jadeja  ...      S Dube            1           0             1
# 243814     S Dube  ...   RA Jadeja            1           0             1
# 243815  RA Jadeja  ...      S Dube            6           0             6
# 243816  RA Jadeja  ...      S Dube            4           0             4
#
#         extras_type is_wicket  player_dismissed dismissal_kind fielder  \
# 124             NaN         0               NaN            NaN     NaN
# 125           wides         0               NaN            NaN     NaN
# 126             NaN         0               NaN            NaN     NaN
# 127             NaN         0               NaN            NaN     NaN
# 128             NaN         0               NaN            NaN     NaN
# ...             ...       ...               ...            ...     ...
# 243812          NaN         0               NaN            NaN     NaN
# 243813          NaN         0               NaN            NaN     NaN
# 243814          NaN         0               NaN            NaN     NaN
# 243815          NaN         0               NaN            NaN     NaN
# 243816          NaN         0               NaN            NaN     NaN
#
#        current_Score
# 124                1
# 125                2
# 126                2
# 127                3
# 128                4
# ...              ...
# 243812           159
# 243813           160
# 243814           161
# 243815           167
# 243816           171
#
# [104595 rows x 21 columns]

# %%
#calculate runs left after each ball using target and currenct score
second_innings['runs_left'] = second_innings['total_runs_x'] - second_innings['current_Score']
second_innings
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           223       2
# 125       335982  Bangalore  Kolkata Knight Riders           223       2
# 126       335982  Bangalore  Kolkata Knight Riders           223       2
# 127       335982  Bangalore  Kolkata Knight Riders           223       2
# 128       335982  Bangalore  Kolkata Knight Riders           223       2
# ...          ...        ...                    ...           ...     ...
# 243812   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243813   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243814   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243815   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243816   1370353  Ahmedabad    Chennai Super Kings           215       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 243812          Chennai Super Kings         Gujarat Titans    14     2
# 243813          Chennai Super Kings         Gujarat Titans    14     3
# 243814          Chennai Super Kings         Gujarat Titans    14     4
# 243815          Chennai Super Kings         Gujarat Titans    14     5
# 243816          Chennai Super Kings         Gujarat Titans    14     6
#
#            batter  ... batsman_runs extra_runs  total_runs_y  extras_type  \
# 124      R Dravid  ...            1          0             1          NaN
# 125      W Jaffer  ...            0          1             1        wides
# 126      W Jaffer  ...            0          0             0          NaN
# 127      W Jaffer  ...            1          0             1          NaN
# 128      R Dravid  ...            1          0             1          NaN
# ...           ...  ...          ...        ...           ...          ...
# 243812     S Dube  ...            1          0             1          NaN
# 243813  RA Jadeja  ...            1          0             1          NaN
# 243814     S Dube  ...            1          0             1          NaN
# 243815  RA Jadeja  ...            6          0             6          NaN
# 243816  RA Jadeja  ...            4          0             4          NaN
#
#         is_wicket player_dismissed  dismissal_kind fielder current_Score  \
# 124             0              NaN             NaN     NaN             1
# 125             0              NaN             NaN     NaN             2
# 126             0              NaN             NaN     NaN             2
# 127             0              NaN             NaN     NaN             3
# 128             0              NaN             NaN     NaN             4
# ...           ...              ...             ...     ...           ...
# 243812          0              NaN             NaN     NaN           159
# 243813          0              NaN             NaN     NaN           160
# 243814          0              NaN             NaN     NaN           161
# 243815          0              NaN             NaN     NaN           167
# 243816          0              NaN             NaN     NaN           171
#
#        runs_left
# 124          222
# 125          221
# 126          221
# 127          220
# 128          219
# ...          ...
# 243812        56
# 243813        55
# 243814        54
# 243815        48
# 243816        44
#
# [104595 rows x 22 columns]

# %%
#calculating balls left after each ball 
second_innings['balls_left'] = 120 - (second_innings['over']*6 +second_innings['ball'])
second_innings
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           223       2
# 125       335982  Bangalore  Kolkata Knight Riders           223       2
# 126       335982  Bangalore  Kolkata Knight Riders           223       2
# 127       335982  Bangalore  Kolkata Knight Riders           223       2
# 128       335982  Bangalore  Kolkata Knight Riders           223       2
# ...          ...        ...                    ...           ...     ...
# 243812   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243813   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243814   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243815   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243816   1370353  Ahmedabad    Chennai Super Kings           215       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 243812          Chennai Super Kings         Gujarat Titans    14     2
# 243813          Chennai Super Kings         Gujarat Titans    14     3
# 243814          Chennai Super Kings         Gujarat Titans    14     4
# 243815          Chennai Super Kings         Gujarat Titans    14     5
# 243816          Chennai Super Kings         Gujarat Titans    14     6
#
#            batter  ... extra_runs total_runs_y  extras_type  is_wicket  \
# 124      R Dravid  ...          0            1          NaN          0
# 125      W Jaffer  ...          1            1        wides          0
# 126      W Jaffer  ...          0            0          NaN          0
# 127      W Jaffer  ...          0            1          NaN          0
# 128      R Dravid  ...          0            1          NaN          0
# ...           ...  ...        ...          ...          ...        ...
# 243812     S Dube  ...          0            1          NaN          0
# 243813  RA Jadeja  ...          0            1          NaN          0
# 243814     S Dube  ...          0            1          NaN          0
# 243815  RA Jadeja  ...          0            6          NaN          0
# 243816  RA Jadeja  ...          0            4          NaN          0
#
#         player_dismissed dismissal_kind  fielder current_Score runs_left  \
# 124                  NaN            NaN      NaN             1       222
# 125                  NaN            NaN      NaN             2       221
# 126                  NaN            NaN      NaN             2       221
# 127                  NaN            NaN      NaN             3       220
# 128                  NaN            NaN      NaN             4       219
# ...                  ...            ...      ...           ...       ...
# 243812               NaN            NaN      NaN           159        56
# 243813               NaN            NaN      NaN           160        55
# 243814               NaN            NaN      NaN           161        54
# 243815               NaN            NaN      NaN           167        48
# 243816               NaN            NaN      NaN           171        44
#
#        balls_left
# 124           119
# 125           118
# 126           117
# 127           116
# 128           115
# ...           ...
# 243812         34
# 243813         33
# 243814         32
# 243815         31
# 243816         30
#
# [104595 rows x 23 columns]

# %%
second_innings
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           223       2
# 125       335982  Bangalore  Kolkata Knight Riders           223       2
# 126       335982  Bangalore  Kolkata Knight Riders           223       2
# 127       335982  Bangalore  Kolkata Knight Riders           223       2
# 128       335982  Bangalore  Kolkata Knight Riders           223       2
# ...          ...        ...                    ...           ...     ...
# 243812   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243813   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243814   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243815   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243816   1370353  Ahmedabad    Chennai Super Kings           215       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 243812          Chennai Super Kings         Gujarat Titans    14     2
# 243813          Chennai Super Kings         Gujarat Titans    14     3
# 243814          Chennai Super Kings         Gujarat Titans    14     4
# 243815          Chennai Super Kings         Gujarat Titans    14     5
# 243816          Chennai Super Kings         Gujarat Titans    14     6
#
#            batter  ... extra_runs total_runs_y  extras_type  is_wicket  \
# 124      R Dravid  ...          0            1          NaN          0
# 125      W Jaffer  ...          1            1        wides          0
# 126      W Jaffer  ...          0            0          NaN          0
# 127      W Jaffer  ...          0            1          NaN          0
# 128      R Dravid  ...          0            1          NaN          0
# ...           ...  ...        ...          ...          ...        ...
# 243812     S Dube  ...          0            1          NaN          0
# 243813  RA Jadeja  ...          0            1          NaN          0
# 243814     S Dube  ...          0            1          NaN          0
# 243815  RA Jadeja  ...          0            6          NaN          0
# 243816  RA Jadeja  ...          0            4          NaN          0
#
#         player_dismissed dismissal_kind  fielder current_Score runs_left  \
# 124                  NaN            NaN      NaN             1       222
# 125                  NaN            NaN      NaN             2       221
# 126                  NaN            NaN      NaN             2       221
# 127                  NaN            NaN      NaN             3       220
# 128                  NaN            NaN      NaN             4       219
# ...                  ...            ...      ...           ...       ...
# 243812               NaN            NaN      NaN           159        56
# 243813               NaN            NaN      NaN           160        55
# 243814               NaN            NaN      NaN           161        54
# 243815               NaN            NaN      NaN           167        48
# 243816               NaN            NaN      NaN           171        44
#
#        balls_left
# 124           119
# 125           118
# 126           117
# 127           116
# 128           115
# ...           ...
# 243812         34
# 243813         33
# 243814         32
# 243815         31
# 243816         30
#
# [104595 rows x 23 columns]

# %% [markdown]
# Getting Wickets

# %%
#calculate the wickets left 
#filling nan values with 0 
second_innings['player_dismissed'] = second_innings['player_dismissed'].fillna("0")

# %%
#filling where 0 is not there and there is a wicket with 1 
second_innings['player_dismissed'] = second_innings['player_dismissed'].apply(lambda x:x if x=="0" else "1")

# %%
#converting the type to int
second_innings['player_dismissed'] = second_innings['player_dismissed'].astype('int')

# %%
# Perform cumulative sum operation
wickets = second_innings.groupby('match_id')['player_dismissed'].cumsum()


# Calculate wickets remaining
second_innings['wickets_remaining'] = 10 - wickets

# %%
second_innings
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           223       2
# 125       335982  Bangalore  Kolkata Knight Riders           223       2
# 126       335982  Bangalore  Kolkata Knight Riders           223       2
# 127       335982  Bangalore  Kolkata Knight Riders           223       2
# 128       335982  Bangalore  Kolkata Knight Riders           223       2
# ...          ...        ...                    ...           ...     ...
# 243812   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243813   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243814   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243815   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243816   1370353  Ahmedabad    Chennai Super Kings           215       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 243812          Chennai Super Kings         Gujarat Titans    14     2
# 243813          Chennai Super Kings         Gujarat Titans    14     3
# 243814          Chennai Super Kings         Gujarat Titans    14     4
# 243815          Chennai Super Kings         Gujarat Titans    14     5
# 243816          Chennai Super Kings         Gujarat Titans    14     6
#
#            batter  ... total_runs_y extras_type  is_wicket  player_dismissed  \
# 124      R Dravid  ...            1         NaN          0                 0
# 125      W Jaffer  ...            1       wides          0                 0
# 126      W Jaffer  ...            0         NaN          0                 0
# 127      W Jaffer  ...            1         NaN          0                 0
# 128      R Dravid  ...            1         NaN          0                 0
# ...           ...  ...          ...         ...        ...               ...
# 243812     S Dube  ...            1         NaN          0                 0
# 243813  RA Jadeja  ...            1         NaN          0                 0
# 243814     S Dube  ...            1         NaN          0                 0
# 243815  RA Jadeja  ...            6         NaN          0                 0
# 243816  RA Jadeja  ...            4         NaN          0                 0
#
#         dismissal_kind fielder  current_Score  runs_left balls_left  \
# 124                NaN     NaN              1        222        119
# 125                NaN     NaN              2        221        118
# 126                NaN     NaN              2        221        117
# 127                NaN     NaN              3        220        116
# 128                NaN     NaN              4        219        115
# ...                ...     ...            ...        ...        ...
# 243812             NaN     NaN            159         56         34
# 243813             NaN     NaN            160         55         33
# 243814             NaN     NaN            161         54         32
# 243815             NaN     NaN            167         48         31
# 243816             NaN     NaN            171         44         30
#
#        wickets_remaining
# 124                   10
# 125                   10
# 126                   10
# 127                   10
# 128                   10
# ...                  ...
# 243812                 5
# 243813                 5
# 243814                 5
# 243815                 5
# 243816                 5
#
# [104595 rows x 24 columns]

# %% [markdown]
# Current Run Rate

# %%
second_innings['crr'] = round((second_innings['current_Score']*6)/(120 - second_innings['balls_left']),2)
second_innings
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           223       2
# 125       335982  Bangalore  Kolkata Knight Riders           223       2
# 126       335982  Bangalore  Kolkata Knight Riders           223       2
# 127       335982  Bangalore  Kolkata Knight Riders           223       2
# 128       335982  Bangalore  Kolkata Knight Riders           223       2
# ...          ...        ...                    ...           ...     ...
# 243812   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243813   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243814   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243815   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243816   1370353  Ahmedabad    Chennai Super Kings           215       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 243812          Chennai Super Kings         Gujarat Titans    14     2
# 243813          Chennai Super Kings         Gujarat Titans    14     3
# 243814          Chennai Super Kings         Gujarat Titans    14     4
# 243815          Chennai Super Kings         Gujarat Titans    14     5
# 243816          Chennai Super Kings         Gujarat Titans    14     6
#
#            batter  ... extras_type is_wicket  player_dismissed  \
# 124      R Dravid  ...         NaN         0                 0
# 125      W Jaffer  ...       wides         0                 0
# 126      W Jaffer  ...         NaN         0                 0
# 127      W Jaffer  ...         NaN         0                 0
# 128      R Dravid  ...         NaN         0                 0
# ...           ...  ...         ...       ...               ...
# 243812     S Dube  ...         NaN         0                 0
# 243813  RA Jadeja  ...         NaN         0                 0
# 243814     S Dube  ...         NaN         0                 0
# 243815  RA Jadeja  ...         NaN         0                 0
# 243816  RA Jadeja  ...         NaN         0                 0
#
#         dismissal_kind  fielder current_Score  runs_left  balls_left  \
# 124                NaN      NaN             1        222         119
# 125                NaN      NaN             2        221         118
# 126                NaN      NaN             2        221         117
# 127                NaN      NaN             3        220         116
# 128                NaN      NaN             4        219         115
# ...                ...      ...           ...        ...         ...
# 243812             NaN      NaN           159         56          34
# 243813             NaN      NaN           160         55          33
# 243814             NaN      NaN           161         54          32
# 243815             NaN      NaN           167         48          31
# 243816             NaN      NaN           171         44          30
#
#        wickets_remaining    crr
# 124                   10   6.00
# 125                   10   6.00
# 126                   10   4.00
# 127                   10   4.50
# 128                   10   4.80
# ...                  ...    ...
# 243812                 5  11.09
# 243813                 5  11.03
# 243814                 5  10.98
# 243815                 5  11.26
# 243816                 5  11.40
#
# [104595 rows x 25 columns]

# %% [markdown]
# Required Run Rate

# %%
second_innings['rrr'] = round((second_innings['runs_left']*6)/(second_innings['balls_left']),2)
second_innings
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           223       2
# 125       335982  Bangalore  Kolkata Knight Riders           223       2
# 126       335982  Bangalore  Kolkata Knight Riders           223       2
# 127       335982  Bangalore  Kolkata Knight Riders           223       2
# 128       335982  Bangalore  Kolkata Knight Riders           223       2
# ...          ...        ...                    ...           ...     ...
# 243812   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243813   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243814   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243815   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243816   1370353  Ahmedabad    Chennai Super Kings           215       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 243812          Chennai Super Kings         Gujarat Titans    14     2
# 243813          Chennai Super Kings         Gujarat Titans    14     3
# 243814          Chennai Super Kings         Gujarat Titans    14     4
# 243815          Chennai Super Kings         Gujarat Titans    14     5
# 243816          Chennai Super Kings         Gujarat Titans    14     6
#
#            batter  ... is_wicket player_dismissed  dismissal_kind  fielder  \
# 124      R Dravid  ...         0                0             NaN      NaN
# 125      W Jaffer  ...         0                0             NaN      NaN
# 126      W Jaffer  ...         0                0             NaN      NaN
# 127      W Jaffer  ...         0                0             NaN      NaN
# 128      R Dravid  ...         0                0             NaN      NaN
# ...           ...  ...       ...              ...             ...      ...
# 243812     S Dube  ...         0                0             NaN      NaN
# 243813  RA Jadeja  ...         0                0             NaN      NaN
# 243814     S Dube  ...         0                0             NaN      NaN
# 243815  RA Jadeja  ...         0                0             NaN      NaN
# 243816  RA Jadeja  ...         0                0             NaN      NaN
#
#         current_Score runs_left  balls_left  wickets_remaining    crr    rrr
# 124                 1       222         119                 10   6.00  11.19
# 125                 2       221         118                 10   6.00  11.24
# 126                 2       221         117                 10   4.00  11.33
# 127                 3       220         116                 10   4.50  11.38
# 128                 4       219         115                 10   4.80  11.43
# ...               ...       ...         ...                ...    ...    ...
# 243812            159        56          34                  5  11.09   9.88
# 243813            160        55          33                  5  11.03  10.00
# 243814            161        54          32                  5  10.98  10.12
# 243815            167        48          31                  5  11.26   9.29
# 243816            171        44          30                  5  11.40   8.80
#
# [104595 rows x 26 columns]

# %% [markdown]
# Finding Winner

# %%
def winner(team):
    return 1 if team['batting_team'] == team['winner'] else 0

# %%
second_innings['results'] = second_innings.apply(winner,axis=1)
second_innings
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           223       2
# 125       335982  Bangalore  Kolkata Knight Riders           223       2
# 126       335982  Bangalore  Kolkata Knight Riders           223       2
# 127       335982  Bangalore  Kolkata Knight Riders           223       2
# 128       335982  Bangalore  Kolkata Knight Riders           223       2
# ...          ...        ...                    ...           ...     ...
# 243812   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243813   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243814   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243815   1370353  Ahmedabad    Chennai Super Kings           215       2
# 243816   1370353  Ahmedabad    Chennai Super Kings           215       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 243812          Chennai Super Kings         Gujarat Titans    14     2
# 243813          Chennai Super Kings         Gujarat Titans    14     3
# 243814          Chennai Super Kings         Gujarat Titans    14     4
# 243815          Chennai Super Kings         Gujarat Titans    14     5
# 243816          Chennai Super Kings         Gujarat Titans    14     6
#
#            batter  ... player_dismissed dismissal_kind  fielder  \
# 124      R Dravid  ...                0            NaN      NaN
# 125      W Jaffer  ...                0            NaN      NaN
# 126      W Jaffer  ...                0            NaN      NaN
# 127      W Jaffer  ...                0            NaN      NaN
# 128      R Dravid  ...                0            NaN      NaN
# ...           ...  ...              ...            ...      ...
# 243812     S Dube  ...                0            NaN      NaN
# 243813  RA Jadeja  ...                0            NaN      NaN
# 243814     S Dube  ...                0            NaN      NaN
# 243815  RA Jadeja  ...                0            NaN      NaN
# 243816  RA Jadeja  ...                0            NaN      NaN
#
#         current_Score  runs_left balls_left  wickets_remaining    crr    rrr  \
# 124                 1        222        119                 10   6.00  11.19
# 125                 2        221        118                 10   6.00  11.24
# 126                 2        221        117                 10   4.00  11.33
# 127                 3        220        116                 10   4.50  11.38
# 128                 4        219        115                 10   4.80  11.43
# ...               ...        ...        ...                ...    ...    ...
# 243812            159         56         34                  5  11.09   9.88
# 243813            160         55         33                  5  11.03  10.00
# 243814            161         54         32                  5  10.98  10.12
# 243815            167         48         31                  5  11.26   9.29
# 243816            171         44         30                  5  11.40   8.80
#
#        results
# 124          0
# 125          0
# 126          0
# 127          0
# 128          0
# ...        ...
# 243812       1
# 243813       1
# 243814       1
# 243815       1
# 243816       1
#
# [104595 rows x 27 columns]

# %% [markdown]
# only taking required columns we need

# %%
required_data = second_innings[['batting_team','bowling_team','city','runs_left','balls_left','wickets_remaining','total_runs_x','crr','rrr','results']]
required_data
# Out:
#                        batting_team           bowling_team       city  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 125     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 126     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 127     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 128     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# ...                             ...                    ...        ...
# 243812          Chennai Super Kings         Gujarat Titans  Ahmedabad
# 243813          Chennai Super Kings         Gujarat Titans  Ahmedabad
# 243814          Chennai Super Kings         Gujarat Titans  Ahmedabad
# 243815          Chennai Super Kings         Gujarat Titans  Ahmedabad
# 243816          Chennai Super Kings         Gujarat Titans  Ahmedabad
#
#         runs_left  balls_left  wickets_remaining  total_runs_x    crr    rrr  \
# 124           222         119                 10           223   6.00  11.19
# 125           221         118                 10           223   6.00  11.24
# 126           221         117                 10           223   4.00  11.33
# 127           220         116                 10           223   4.50  11.38
# 128           219         115                 10           223   4.80  11.43
# ...           ...         ...                ...           ...    ...    ...
# 243812         56          34                  5           215  11.09   9.88
# 243813         55          33                  5           215  11.03  10.00
# 243814         54          32                  5           215  10.98  10.12
# 243815         48          31                  5           215  11.26   9.29
# 243816         44          30                  5           215  11.40   8.80
#
#         results
# 124           0
# 125           0
# 126           0
# 127           0
# 128           0
# ...         ...
# 243812        1
# 243813        1
# 243814        1
# 243815        1
# 243816        1
#
# [104595 rows x 10 columns]
